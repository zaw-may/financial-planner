# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
import re

# %% [markdown]
# Importing Data

# %%
raw_data = pd.read_csv('..\Sample Datasets\credit_data_train.csv', low_memory = False)
test = pd.read_csv('..\Sample Datasets\credit_data_test.csv', low_memory = False)

# %% [markdown]
# Exploring Data

# %%
raw_data.head(3)

# %%
print(raw_data.shape)
raw_data.describe()

# %%
raw_data.dtypes

# %% [markdown]
# Removing Unnecessary Columns

# %%
drop_col = ['ID', 'Name', 'SSN', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Num_of_Loan', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix']
df = raw_data.drop(drop_col, axis=1).copy()
df.head(3)
# Out:
#   Customer_ID     Month   Age Occupation Annual_Income  Monthly_Inhand_Salary  \
# 0   CUS_0xd40   January    23  Scientist      19114.12            1824.843333
# 1   CUS_0xd40  February    23  Scientist      19114.12                    NaN
# 2   CUS_0xd40     March  -500  Scientist      19114.12                    NaN
#
#    Interest_Rate                                       Type_of_Loan  \
# 0              3  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1              3  Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2              3  Auto Loan, Credit-Builder Loan, Personal Loan,...
#
#    Delay_from_due_date Num_of_Delayed_Payment Outstanding_Debt  \
# 0                    3                      7           809.98
# 1                   -1                    NaN           809.98
# 2                    3                      7           809.98
#
#    Credit_Utilization_Ratio     Credit_History_Age Payment_of_Min_Amount  \
# 0                 26.822620  22 Years and 1 Months                    No
# 1                 31.944960                    NaN                    No
# 2                 28.609352  22 Years and 3 Months                    No
#
#    Total_EMI_per_month Amount_invested_monthly  \
# 0            49.574949        80.4152954390025
# 1            49.574949        118.280221622367
# 2            49.574949         81.699521264648
#
#                  Payment_Behaviour   Monthly_Balance Credit_Score
# 0  High_spent_Small_value_payments  312.494088679437         Good
# 1   Low_spent_Large_value_payments  284.629162496072         Good
# 2  Low_spent_Medium_value_payments  331.209862853791         Good

# %% [markdown]
# Checking Null Values

# %%
df.isnull().sum()

# %% [markdown]
# Pre-processing Data

# %%
def check_and_copy_row_data(df, column_name):
    last_valid_value = {}

    for i in range(len(df)):
        customer_id = df.loc[i, 'Customer_ID']
        
        if pd.isnull(df.loc[i, column_name]) or df.loc[i, column_name] == '':
            if customer_id in last_valid_value:
                df.loc[i, column_name] = last_valid_value[customer_id]
                print(f"Filled missing value at index {i} with last valid value for Customer_ID {customer_id}.")
            else:
                j = i + 1
                while j < len(df) and (pd.isnull(df.loc[j, column_name]) or df.loc[j, column_name] == ''):
                    j += 1
                if j < len(df) and df.loc[j, 'Customer_ID'] == customer_id:
                    df.loc[i, column_name] = df.loc[j, column_name]
                    print(f"Filled missing value at index {i} with value from index {j}.")
                else:
                    print(f"No valid value found for Customer_ID {customer_id} at index {i}.")
        else:
            last_valid_value[customer_id] = df.loc[i, column_name]

    return df

# %%
df['Monthly_Inhand_Salary'].unique()
# Out:
# array([ 1824.84333333,  3037.98666667, 12187.22      , ...,
#         3097.00833333,  1929.90666667,  3359.41583333])

# %%
filtered_df = df[df['Customer_ID'] == 'CUS_0x5c7d'] #CUS_0x5c7d #CUS_0x95ee
print(filtered_df['Monthly_Inhand_Salary'])
# Out:
# 89672    661.321667
# 89673    661.321667
# 89674    661.321667
# 89675    661.321667
# 89676    661.321667
# 89677    661.321667
# 89678    661.321667
# 89679    661.321667
# Name: Monthly_Inhand_Salary, dtype: float64

# %%
df['Monthly_Inhand_Salary'].isnull().sum()
# Out:
# 0

# %%
df['Monthly_Inhand_Salary'] = check_and_copy_row_data(df, 'Monthly_Inhand_Salary')
# Out:
# Filled missing value at index 1 with last valid value for Customer_ID CUS_0xd40.
# Filled missing value at index 2 with last valid value for Customer_ID CUS_0xd40.
# Filled missing value at index 3 with last valid value for Customer_ID CUS_0xd40.
# Filled missing value at index 5 with last valid value for Customer_ID CUS_0xd40.
# Filled missing value at index 11 with last valid value for Customer_ID CUS_0x21b1.
# Filled missing value at index 14 with last valid value for Customer_ID CUS_0x21b1.
# Filled missing value at index 18 with last valid value for Customer_ID CUS_0x2dbc.
# Filled missing value at index 33 with last valid value for Customer_ID CUS_0x1cdb.
# Filled missing value at index 37 with last valid value for Customer_ID CUS_0x1cdb.
# Filled missing value at index 40 with value from index 41.
# Filled missing value at index 53 with last valid value for Customer_ID CUS_0x284a.
# Filled missing value at index 54 with last valid value for Customer_ID CUS_0x284a.
# Filled missing value at index 56 with value from index 57.
# Filled missing value at index 58 with last valid value for Customer_ID CUS_0x5407.
# Filled missing value at index 62 with last valid value for Customer_ID CUS_0x5407.
# Filled missing value at index 66 with last valid value for Customer_ID CUS_0x4157.
# Filled missing value at index 67 with last valid value for Customer_ID CUS_0x4157.
# Filled missing value at index 79 with last valid value for Customer_ID CUS_0xba08.
# Filled missing value at index 82 with last valid value for Customer_ID CUS_0xa66b.
# Filled missing value at index 94 with last valid value for Customer_ID CUS_0xc0ab.
# Filled missing value at index 98 with last valid value for Customer_ID CUS_0x3e45.
# Filled missing value at index 104 with value from index 105.
# Filled missing value at index 110 with last valid value for Customer_ID CUS_0x6c66.
# Filled missing value at index 113 with last valid value for Customer_ID CUS_0xff4.
# Filled missing value at index 125 with last valid value for Customer_ID CUS_0x33d2.
# Filled missing value at index 126 with last valid value for Customer_ID CUS_0x33d2.
# Filled missing value at index 128 with value from index 129.
# Filled missing value at index 147 with last valid value for Customer_ID CUS_0x3553.
# Filled missing value at index 158 with last valid value for Customer_ID CUS_0x4100.
# Filled missing value at index 164 with last valid value for Customer_ID CUS_0x132f.
# Filled missing value at index 165 with last valid value for Customer_ID CUS_0x132f.
# Filled missing value at index 167 with last valid value for Customer_ID CUS_0x132f.
# Filled missing value at index 168 with value from index 169.
# Filled missing value at index 179 with last valid value for Customer_ID CUS_0xac86.
# Filled missing value at index 193 with last valid value for Customer_ID CUS_0xa5f9.
# Filled missing value at index 195 with last valid value for Customer_ID CUS_0xa5f9.
# Filled missing value at index 203 with last valid value for Customer_ID CUS_0x4d43.
# Filled missing value at index 204 with last valid value for Customer_ID CUS_0x4d43.
# Filled missing value at index 211 with last valid value for Customer_ID CUS_0xb95f.
# Filled missing value at index 215 with last valid value for Customer_ID CUS_0xb95f.
# Filled missing value at index 216 with value from index 217.
# Filled missing value at index 223 with last valid value for Customer_ID CUS_0x3edc.
# Filled missing value at index 227 with last valid value for Customer_ID CUS_0xbffe.
# Filled missing value at index 228 with last valid value for Customer_ID CUS_0xbffe.
# Filled missing value at index 229 with last valid value for Customer_ID CUS_0xbffe.
# Filled missing value at index 236 with last valid value for Customer_ID CUS_0xb681.
# Filled missing value at index 249 with last valid value for Customer_ID CUS_0x6048.
# Filled missing value at index 250 with last valid value for Customer_ID CUS_0x6048.
# Filled missing value at index 252 with last valid value for Customer_ID CUS_0x6048.
# Filled missing value at index 261 with last valid value for Customer_ID CUS_0x95b5.
# Filled missing value at index 266 with last valid value for Customer_ID CUS_0x4004.
# Filled missing value at index 267 with last valid value for Customer_ID CUS_0x4004.
# Filled missing value at index 272 with value from index 273.
# Filled missing value at index 275 with last valid value for Customer_ID CUS_0xb101.
# Filled missing value at index 279 with last valid value for Customer_ID CUS_0xb101.
# Filled missing value at index 293 with last valid value for Customer_ID CUS_0x4080.
# Filled missing value at index 294 with last valid value for Customer_ID CUS_0x4080.
# Filled missing value at index 297 with last valid value for Customer_ID CUS_0x706a.
# Filled missing value at index 299 with last valid value for Customer_ID CUS_0x706a.
# Filled missing value at index 323 with last valid value for Customer_ID CUS_0xb5ff.
# Filled missing value at index 324 with last valid value for Customer_ID CUS_0xb5ff.
# Filled missing value at index 329 with last valid value for Customer_ID CUS_0x6a1b.
# Filled missing value at index 330 with last valid value for Customer_ID CUS_0x6a1b.
# Filled missing value at index 339 with last valid value for Customer_ID CUS_0x9bc1.
# Filled missing value at index 365 with last valid value for Customer_ID CUS_0x8e9b.
# Filled missing value at index 366 with last valid value for Customer_ID CUS_0x8e9b.
# Filled missing value at index 367 with last valid value for Customer_ID CUS_0x8e9b.
# Filled missing value at index 369 with last valid value for Customer_ID CUS_0x609d.
# Filled missing value at index 384 with value from index 385.
# Filled missing value at index 388 with last valid value for Customer_ID CUS_0x9b3c.
# Filled missing value at index 391 with last valid value for Customer_ID CUS_0x9b3c.
# Filled missing value at index 401 with last valid value for Customer_ID CUS_0xb14.
# Filled missing value at index 419 with last valid value for Customer_ID CUS_0xbe1b.
# Filled missing value at index 422 with last valid value for Customer_ID CUS_0xbe1b.
# Filled missing value at index 439 with last valid value for Customer_ID CUS_0x6ffb.
# Filled missing value at index 444 with last valid value for Customer_ID CUS_0x4315.
# Filled missing value at index 454 with last valid value for Customer_ID CUS_0x3f5b.
# Filled missing value at index 459 with last valid value for Customer_ID CUS_0x9d78.
# Filled missing value at index 461 with last valid value for Customer_ID CUS_0x9d78.
# Filled missing value at index 478 with last valid value for Customer_ID CUS_0x8f17.
# Filled missing value at index 495 with last valid value for Customer_ID CUS_0x7504.
# Filled missing value at index 498 with last valid value for Customer_ID CUS_0x774.
# Filled missing value at index 500 with last valid value for Customer_ID CUS_0x774.
# Filled missing value at index 503 with last valid value for Customer_ID CUS_0x774.
# Filled missing value at index 508 with last valid value for Customer_ID CUS_0x9f70.
# Filled missing value at index 515 with last valid value for Customer_ID CUS_0xab76.
# Filled missing value at index 525 with last valid value for Customer_ID CUS_0x5cdf.
# Filled missing value at index 527 with last valid value for Customer_ID CUS_0x5cdf.
# Filled missing value at index 529 with last valid value for Customer_ID CUS_0x2184.
# Filled missing value at index 543 with last valid value for Customer_ID CUS_0xa156.
# Filled missing value at index 545 with last valid value for Customer_ID CUS_0x74f2.
# Filled missing value at index 550 with last valid value for Customer_ID CUS_0x74f2.
# Filled missing value at index 554 with last valid value for Customer_ID CUS_0x308b.
# Filled missing value at index 558 with last valid value for Customer_ID CUS_0x308b.
# Filled missing value at index 567 with last valid value for Customer_ID CUS_0x2827.
# Filled missing value at index 575 with last valid value for Customer_ID CUS_0xa295.
# Filled missing value at index 579 with last valid value for Customer_ID CUS_0x6c2e.
# Filled missing value at index 580 with last valid value for Customer_ID CUS_0x6c2e.
# Filled missing value at index 589 with last valid value for Customer_ID CUS_0x384c.
# Filled missing value at index 603 with last valid value for Customer_ID CUS_0x36ab.
# Filled missing value at index 615 with last valid value for Customer_ID CUS_0x6649.
# Filled missing value at index 620 with last valid value for Customer_ID CUS_0x6856.
# Filled missing value at index 621 with last valid value for Customer_ID CUS_0x6856.
# Filled missing value at index 647 with last valid value for Customer_ID CUS_0x78e0.
# Filled missing value at index 659 with last valid value for Customer_ID CUS_0xe2c.
# Filled missing value at index 667 with last valid value for Customer_ID CUS_0x36bb.
# Filled missing value at index 686 with last valid value for Customer_ID CUS_0x1e70.
# Filled missing value at index 691 with last valid value for Customer_ID CUS_0xa335.
# Filled missing value at index 693 with last valid value for Customer_ID CUS_0xa335.
# Filled missing value at index 698 with last valid value for Customer_ID CUS_0x71e0.
# Filled missing value at index 700 with last valid value for Customer_ID CUS_0x71e0.
# Filled missing value at index 709 with last valid value for Customer_ID CUS_0x4af0.
# Filled missing value at index 712 with value from index 714.
# Filled missing value at index 713 with value from index 714.
# Filled missing value at index 720 with value from index 721.
# Filled missing value at index 728 with value from index 730.
# Filled missing value at index 729 with value from index 730.
# Filled missing value at index 731 with last valid value for Customer_ID CUS_0x2652.
# Filled missing value at index 736 with value from index 737.
# Filled missing value at index 738 with last valid value for Customer_ID CUS_0x259a.
# Filled missing value at index 745 with last valid value for Customer_ID CUS_0x28b5.
# Filled missing value at index 759 with last valid value for Customer_ID CUS_0x8643.
# Filled missing value at index 772 with last valid value for Customer_ID CUS_0x3f04.
# Filled missing value at index 788 with last valid value for Customer_ID CUS_0x398d.
# Filled missing value at index 793 with last valid value for Customer_ID CUS_0x618b.
# Filled missing value at index 806 with last valid value for Customer_ID CUS_0x7250.
# Filled missing value at index 813 with last valid value for Customer_ID CUS_0x6435.
# Filled missing value at index 820 with last valid value for Customer_ID CUS_0xb6ad.
# Filled missing value at index 827 with last valid value for Customer_ID CUS_0x7878.
# Filled missing value at index 829 with last valid value for Customer_ID CUS_0x7878.
# Filled missing value at index 834 with last valid value for Customer_ID CUS_0x35b5.
# Filled missing value at index 841 with last valid value for Customer_ID CUS_0x7a0f.
# Filled missing value at index 844 with last valid value for Customer_ID CUS_0x7a0f.
# Filled missing value at index 848 with value from index 849.
# Filled missing value at index 867 with last valid value for Customer_ID CUS_0x9073.
# Filled missing value at index 869 with last valid value for Customer_ID CUS_0x9073.
# Filled missing value at index 873 with last valid value for Customer_ID CUS_0x2813.
# Filled missing value at index 879 with last valid value for Customer_ID CUS_0x2813.
# Filled missing value at index 891 with last valid value for Customer_ID CUS_0x8c69.
# Filled missing value at index 896 with value from index 897.
# Filled missing value at index 904 with value from index 905.
# Filled missing value at index 908 with last valid value for Customer_ID CUS_0x7586.
# Filled missing value at index 911 with last valid value for Customer_ID CUS_0x7586.
# Filled missing value at index 915 with last valid value for Customer_ID CUS_0x9c67.
# Filled missing value at index 921 with last valid value for Customer_ID CUS_0x7caf.
# Filled missing value at index 922 with last valid value for Customer_ID CUS_0x7caf.
# Filled missing value at index 939 with last valid value for Customer_ID CUS_0x5e17.
# Filled missing value at index 941 with last valid value for Customer_ID CUS_0x5e17.
# Filled missing value at index 942 with last valid value for Customer_ID CUS_0x5e17.
# Filled missing value at index 959 with last valid value for Customer_ID CUS_0x567b.
# Filled missing value at index 960 with value from index 961.
# Filled missing value at index 972 with last valid value for Customer_ID CUS_0x8a04.
# Filled missing value at index 975 with last valid value for Customer_ID CUS_0x8a04.
# Filled missing value at index 984 with value from index 985.
# Filled missing value at index 991 with last valid value for Customer_ID CUS_0x21e6.
# Filled missing value at index 1005 with last valid value for Customer_ID CUS_0x3187.
# Filled missing value at index 1024 with value from index 1025.
# Filled missing value at index 1033 with last valid value for Customer_ID CUS_0x2947.
# Filled missing value at index 1034 with last valid value for Customer_ID CUS_0x2947.
# Filled missing value at index 1048 with value from index 1049.
# Filled missing value at index 1053 with last valid value for Customer_ID CUS_0xc3b7.
# Filled missing value at index 1060 with last valid value for Customer_ID CUS_0x1e9b.
# Filled missing value at index 1073 with last valid value for Customer_ID CUS_0xae51.
# Filled missing value at index 1076 with last valid value for Customer_ID CUS_0xae51.
# Filled missing value at index 1078 with last valid value for Customer_ID CUS_0xae51.
# Filled missing value at index 1082 with last valid value for Customer_ID CUS_0xb7ef.
# Filled missing value at index 1084 with last valid value for Customer_ID CUS_0xb7ef.
# Filled missing value at index 1086 with last valid value for Customer_ID CUS_0xb7ef.
# Filled missing value at index 1088 with value from index 1089.
# Filled missing value at index 1091 with last valid value for Customer_ID CUS_0xb288.
# Filled missing value at index 1093 with last valid value for Customer_ID CUS_0xb288.
# Filled missing value at index 1097 with last valid value for Customer_ID CUS_0x7a22.
# Filled missing value at index 1101 with last valid value for Customer_ID CUS_0x7a22.
# Filled missing value at index 1103 with last valid value for Customer_ID CUS_0x7a22.
# Filled missing value at index 1106 with last valid value for Customer_ID CUS_0x9495.
# Filled missing value at index 1114 with last valid value for Customer_ID CUS_0x64f1.
# Filled missing value at index 1128 with value from index 1129.
# Filled missing value at index 1133 with last valid value for Customer_ID CUS_0xc1c9.
# Filled missing value at index 1157 with last valid value for Customer_ID CUS_0x682f.
# Filled missing value at index 1161 with last valid value for Customer_ID CUS_0x4831.
# Filled missing value at index 1173 with last valid value for Customer_ID CUS_0x32a5.
# Filled missing value at index 1178 with last valid value for Customer_ID CUS_0x710f.
# Filled missing value at index 1180 with last valid value for Customer_ID CUS_0x710f.
# Filled missing value at index 1182 with last valid value for Customer_ID CUS_0x710f.
# Filled missing value at index 1184 with value from index 1185.
# Filled missing value at index 1188 with last valid value for Customer_ID CUS_0xa54b.
# Filled missing value at index 1190 with last valid value for Customer_ID CUS_0xa54b.
# Filled missing value at index 1192 with value from index 1194.
# Filled missing value at index 1193 with value from index 1194.
# Filled missing value at index 1205 with last valid value for Customer_ID CUS_0xb000.
# Filled missing value at index 1208 with value from index 1209.
# Filled missing value at index 1213 with last valid value for Customer_ID CUS_0x2584.
# Filled missing value at index 1226 with last valid value for Customer_ID CUS_0xc341.
# Filled missing value at index 1228 with last valid value for Customer_ID CUS_0xc341.
# Filled missing value at index 1232 with value from index 1237.
# Filled missing value at index 1233 with value from index 1237.
# Filled missing value at index 1234 with value from index 1237.
# Filled missing value at index 1235 with value from index 1237.
# Filled missing value at index 1236 with value from index 1237.
# Filled missing value at index 1240 with value from index 1241.
# Filled missing value at index 1243 with last valid value for Customer_ID CUS_0xb7a1.
# Filled missing value at index 1253 with last valid value for Customer_ID CUS_0x31d5.
# Filled missing value at index 1269 with last valid value for Customer_ID CUS_0x6617.
# Filled missing value at index 1279 with last valid value for Customer_ID CUS_0x5b80.
# Filled missing value at index 1285 with last valid value for Customer_ID CUS_0xa548.
# Filled missing value at index 1288 with value from index 1289.
# Filled missing value at index 1293 with last valid value for Customer_ID CUS_0xb9ea.
# Filled missing value at index 1297 with last valid value for Customer_ID CUS_0x54c0.
# Filled missing value at index 1298 with last valid value for Customer_ID CUS_0x54c0.
# Filled missing value at index 1304 with value from index 1306.
# Filled missing value at index 1305 with value from index 1306.
# Filled missing value at index 1309 with last valid value for Customer_ID CUS_0x258b.
# Filled missing value at index 1319 with last valid value for Customer_ID CUS_0x4bb4.
# Filled missing value at index 1323 with last valid value for Customer_ID CUS_0x8e75.
# Filled missing value at index 1331 with last valid value for Customer_ID CUS_0xf95.
# Filled missing value at index 1335 with last valid value for Customer_ID CUS_0xf95.
# Filled missing value at index 1342 with last valid value for Customer_ID CUS_0x4028.
# Filled missing value at index 1344 with value from index 1345.
# Filled missing value at index 1347 with last valid value for Customer_ID CUS_0x8db8.
# Filled missing value at index 1348 with last valid value for Customer_ID CUS_0x8db8.
# Filled missing value at index 1349 with last valid value for Customer_ID CUS_0x8db8.
# Filled missing value at index 1354 with last valid value for Customer_ID CUS_0x1e63.
# Filled missing value at index 1359 with last valid value for Customer_ID CUS_0x1e63.
# Filled missing value at index 1360 with value from index 1361.
# Filled missing value at index 1362 with last valid value for Customer_ID CUS_0x4948.
# Filled missing value at index 1363 with last valid value for Customer_ID CUS_0x4948.
# Filled missing value at index 1365 with last valid value for Customer_ID CUS_0x4948.
# Filled missing value at index 1368 with value from index 1369.
# Filled missing value at index 1375 with last valid value for Customer_ID CUS_0xc37b.
# Filled missing value at index 1378 with last valid value for Customer_ID CUS_0xfcc.
# Filled missing value at index 1389 with last valid value for Customer_ID CUS_0x64ce.
# Filled missing value at index 1399 with last valid value for Customer_ID CUS_0x9574.
# Filled missing value at index 1400 with value from index 1401.
# Filled missing value at index 1411 with last valid value for Customer_ID CUS_0x661b.
# Filled missing value at index 1415 with last valid value for Customer_ID CUS_0x661b.
# Filled missing value at index 1419 with last valid value for Customer_ID CUS_0xc51.
# Filled missing value at index 1424 with value from index 1425.
# Filled missing value at index 1427 with last valid value for Customer_ID CUS_0x9536.
# Filled missing value at index 1430 with last valid value for Customer_ID CUS_0x9536.
# Filled missing value at index 1436 with last valid value for Customer_ID CUS_0xc5a0.
# Filled missing value at index 1438 with last valid value for Customer_ID CUS_0xc5a0.
# Filled missing value at index 1440 with value from index 1442.
# Filled missing value at index 1441 with value from index 1442.
# Filled missing value at index 1443 with last valid value for Customer_ID CUS_0xb282.
# Filled missing value at index 1444 with last valid value for Customer_ID CUS_0xb282.
# Filled missing value at index 1445 with last valid value for Customer_ID CUS_0xb282.
# Filled missing value at index 1453 with last valid value for Customer_ID CUS_0xb9b8.
# Filled missing value at index 1458 with last valid value for Customer_ID CUS_0x3e81.
# Filled missing value at index 1467 with last valid value for Customer_ID CUS_0x3702.
# Filled missing value at index 1472 with value from index 1474.
# Filled missing value at index 1473 with value from index 1474.
# Filled missing value at index 1485 with last valid value for Customer_ID CUS_0x21be.
# Filled missing value at index 1490 with last valid value for Customer_ID CUS_0x8c1f.
# Filled missing value at index 1496 with value from index 1497.
# Filled missing value at index 1500 with last valid value for Customer_ID CUS_0x67e1.
# Filled missing value at index 1506 with last valid value for Customer_ID CUS_0x1c06.
# Filled missing value at index 1510 with last valid value for Customer_ID CUS_0x1c06.
# Filled missing value at index 1526 with last valid value for Customer_ID CUS_0x9a4a.
# Filled missing value at index 1527 with last valid value for Customer_ID CUS_0x9a4a.
# Filled missing value at index 1530 with last valid value for Customer_ID CUS_0x100b.
# Filled missing value at index 1536 with value from index 1538.
# Filled missing value at index 1537 with value from index 1538.
# Filled missing value at index 1542 with last valid value for Customer_ID CUS_0x6325.
# Filled missing value at index 1548 with last valid value for Customer_ID CUS_0x4e3c.
# Filled missing value at index 1551 with last valid value for Customer_ID CUS_0x4e3c.
# Filled missing value at index 1556 with last valid value for Customer_ID CUS_0xb217.
# Filled missing value at index 1567 with last valid value for Customer_ID CUS_0xb374.
# Filled missing value at index 1576 with value from index 1577.
# Filled missing value at index 1580 with last valid value for Customer_ID CUS_0x8a4b.
# Filled missing value at index 1593 with last valid value for Customer_ID CUS_0x3e2d.
# Filled missing value at index 1602 with last valid value for Customer_ID CUS_0x493c.
# Filled missing value at index 1627 with last valid value for Customer_ID CUS_0x9f7e.
# Filled missing value at index 1636 with last valid value for Customer_ID CUS_0x23a6.
# Filled missing value at index 1650 with last valid value for Customer_ID CUS_0x4ea5.
# Filled missing value at index 1651 with last valid value for Customer_ID CUS_0x4ea5.
# Filled missing value at index 1652 with last valid value for Customer_ID CUS_0x4ea5.
# Filled missing value at index 1653 with last valid value for Customer_ID CUS_0x4ea5.
# Filled missing value at index 1659 with last valid value for Customer_ID CUS_0x8208.
# Filled missing value at index 1660 with last valid value for Customer_ID CUS_0x8208.
# Filled missing value at index 1664 with value from index 1665.
# Filled missing value at index 1688 with value from index 1689.
# Filled missing value at index 1692 with last valid value for Customer_ID CUS_0x5d94.
# Filled missing value at index 1698 with last valid value for Customer_ID CUS_0x3ef5.
# Filled missing value at index 1705 with last valid value for Customer_ID CUS_0xbda3.
# Filled missing value at index 1706 with last valid value for Customer_ID CUS_0xbda3.
# Filled missing value at index 1709 with last valid value for Customer_ID CUS_0xbda3.
# Filled missing value at index 1712 with value from index 1713.
# Filled missing value at index 1714 with last valid value for Customer_ID CUS_0x29fd.
# Filled missing value at index 1721 with last valid value for Customer_ID CUS_0xbbf3.
# Filled missing value at index 1738 with last valid value for Customer_ID CUS_0xb4be.
# Filled missing value at index 1744 with value from index 1745.
# Filled missing value at index 1747 with last valid value for Customer_ID CUS_0xa203.
# Filled missing value at index 1750 with last valid value for Customer_ID CUS_0xa203.
# Filled missing value at index 1758 with last valid value for Customer_ID CUS_0xa7c3.
# Filled missing value at index 1764 with last valid value for Customer_ID CUS_0x76e7.
# Filled missing value at index 1774 with last valid value for Customer_ID CUS_0x46d4.
# Filled missing value at index 1775 with last valid value for Customer_ID CUS_0x46d4.
# Filled missing value at index 1781 with last valid value for Customer_ID CUS_0x396e.
# Filled missing value at index 1782 with last valid value for Customer_ID CUS_0x396e.
# Filled missing value at index 1789 with last valid value for Customer_ID CUS_0x74f5.
# Filled missing value at index 1796 with last valid value for Customer_ID CUS_0xb9e5.
# Filled missing value at index 1800 with value from index 1801.
# Filled missing value at index 1820 with last valid value for Customer_ID CUS_0xbcb9.
# Filled missing value at index 1826 with last valid value for Customer_ID CUS_0xae95.
# Filled missing value at index 1859 with last valid value for Customer_ID CUS_0xa47.
# Filled missing value at index 1877 with last valid value for Customer_ID CUS_0x1452.
# Filled missing value at index 1883 with last valid value for Customer_ID CUS_0x76cf.
# Filled missing value at index 1888 with value from index 1890.
# Filled missing value at index 1889 with value from index 1890.
# Filled missing value at index 1891 with last valid value for Customer_ID CUS_0x703f.
# Filled missing value at index 1898 with last valid value for Customer_ID CUS_0x572.
# Filled missing value at index 1909 with last valid value for Customer_ID CUS_0x104e.
# Filled missing value at index 1913 with last valid value for Customer_ID CUS_0x6f38.
# Filled missing value at index 1919 with last valid value for Customer_ID CUS_0x6f38.
# Filled missing value at index 1920 with value from index 1921.
# Filled missing value at index 1923 with last valid value for Customer_ID CUS_0x7b3c.
# Filled missing value at index 1926 with last valid value for Customer_ID CUS_0x7b3c.
# Filled missing value at index 1930 with last valid value for Customer_ID CUS_0x709d.
# Filled missing value at index 1936 with value from index 1937.
# Filled missing value at index 1942 with last valid value for Customer_ID CUS_0xc434.
# Filled missing value at index 1945 with last valid value for Customer_ID CUS_0x8a12.
# Filled missing value at index 1953 with last valid value for Customer_ID CUS_0x4eb4.
# Filled missing value at index 1970 with last valid value for Customer_ID CUS_0x8c9a.
# Filled missing value at index 1972 with last valid value for Customer_ID CUS_0x8c9a.
# Filled missing value at index 1976 with value from index 1977.
# Filled missing value at index 1983 with last valid value for Customer_ID CUS_0x2c5e.
# Filled missing value at index 1987 with last valid value for Customer_ID CUS_0x70d5.
# Filled missing value at index 1989 with last valid value for Customer_ID CUS_0x70d5.
# Filled missing value at index 1994 with last valid value for Customer_ID CUS_0xb052.
# Filled missing value at index 2003 with last valid value for Customer_ID CUS_0x7c34.
# Filled missing value at index 2016 with value from index 2017.
# Filled missing value at index 2027 with last valid value for Customer_ID CUS_0x41b7.
# Filled missing value at index 2037 with last valid value for Customer_ID CUS_0x9095.
# Filled missing value at index 2039 with last valid value for Customer_ID CUS_0x9095.
# Filled missing value at index 2045 with last valid value for Customer_ID CUS_0xa05f.
# Filled missing value at index 2054 with last valid value for Customer_ID CUS_0x309d.
# Filled missing value at index 2060 with last valid value for Customer_ID CUS_0xa522.
# Filled missing value at index 2061 with last valid value for Customer_ID CUS_0xa522.
# Filled missing value at index 2064 with value from index 2065.
# Filled missing value at index 2067 with last valid value for Customer_ID CUS_0x8a6e.
# Filled missing value at index 2069 with last valid value for Customer_ID CUS_0x8a6e.
# Filled missing value at index 2070 with last valid value for Customer_ID CUS_0x8a6e.
# Filled missing value at index 2075 with last valid value for Customer_ID CUS_0x77d1.
# Filled missing value at index 2078 with last valid value for Customer_ID CUS_0x77d1.
# Filled missing value at index 2082 with last valid value for Customer_ID CUS_0xde6.
# Filled missing value at index 2084 with last valid value for Customer_ID CUS_0xde6.
# Filled missing value at index 2088 with value from index 2089.
# Filled missing value at index 2090 with last valid value for Customer_ID CUS_0xa672.
# Filled missing value at index 2096 with value from index 2098.
# Filled missing value at index 2097 with value from index 2098.
# Filled missing value at index 2121 with last valid value for Customer_ID CUS_0xbd08.
# Filled missing value at index 2124 with last valid value for Customer_ID CUS_0xbd08.
# Filled missing value at index 2127 with last valid value for Customer_ID CUS_0xbd08.
# Filled missing value at index 2130 with last valid value for Customer_ID CUS_0x6b44.
# Filled missing value at index 2134 with last valid value for Customer_ID CUS_0x6b44.
# Filled missing value at index 2151 with last valid value for Customer_ID CUS_0x5228.
# Filled missing value at index 2158 with last valid value for Customer_ID CUS_0x2e6e.
# Filled missing value at index 2165 with last valid value for Customer_ID CUS_0x280b.
# Filled missing value at index 2166 with last valid value for Customer_ID CUS_0x280b.
# Filled missing value at index 2168 with value from index 2169.
# Filled missing value at index 2178 with last valid value for Customer_ID CUS_0xa1d6.
# Filled missing value at index 2182 with last valid value for Customer_ID CUS_0xa1d6.
# Filled missing value at index 2191 with last valid value for Customer_ID CUS_0x8b12.
# Filled missing value at index 2192 with value from index 2193.
# Filled missing value at index 2194 with last valid value for Customer_ID CUS_0xa459.
# Filled missing value at index 2204 with last valid value for Customer_ID CUS_0xf23.
# Filled missing value at index 2220 with last valid value for Customer_ID CUS_0x728f.
# Filled missing value at index 2225 with last valid value for Customer_ID CUS_0xd05.
# Filled missing value at index 2228 with last valid value for Customer_ID CUS_0xd05.
# Filled missing value at index 2236 with last valid value for Customer_ID CUS_0x3cf7.
# Filled missing value at index 2238 with last valid value for Customer_ID CUS_0x3cf7.
# Filled missing value at index 2249 with last valid value for Customer_ID CUS_0x32ce.
# Filled missing value at index 2251 with last valid value for Customer_ID CUS_0x32ce.
# Filled missing value at index 2259 with last valid value for Customer_ID CUS_0x9b4c.
# Filled missing value at index 2286 with last valid value for Customer_ID CUS_0x9a58.
# Filled missing value at index 2291 with last valid value for Customer_ID CUS_0x409e.
# Filled missing value at index 2293 with last valid value for Customer_ID CUS_0x409e.
# Filled missing value at index 2302 with last valid value for Customer_ID CUS_0x532d.
# Filled missing value at index 2303 with last valid value for Customer_ID CUS_0x532d.
# Filled missing value at index 2305 with last valid value for Customer_ID CUS_0xadb7.
# Filled missing value at index 2306 with last valid value for Customer_ID CUS_0xadb7.
# Filled missing value at index 2307 with last valid value for Customer_ID CUS_0xadb7.
# Filled missing value at index 2311 with last valid value for Customer_ID CUS_0xadb7.
# Filled missing value at index 2316 with last valid value for Customer_ID CUS_0xa9ca.
# Filled missing value at index 2320 with value from index 2321.
# Filled missing value at index 2326 with last valid value for Customer_ID CUS_0x69a9.
# Filled missing value at index 2340 with last valid value for Customer_ID CUS_0x479.
# Filled missing value at index 2345 with last valid value for Customer_ID CUS_0x3b5d.
# Filled missing value at index 2355 with last valid value for Customer_ID CUS_0x9167.
# Filled missing value at index 2360 with value from index 2361.
# Filled missing value at index 2363 with last valid value for Customer_ID CUS_0x4a5b.
# Filled missing value at index 2371 with last valid value for Customer_ID CUS_0xfdd.
# Filled missing value at index 2387 with last valid value for Customer_ID CUS_0x6387.
# Filled missing value at index 2388 with last valid value for Customer_ID CUS_0x6387.
# Filled missing value at index 2390 with last valid value for Customer_ID CUS_0x6387.
# Filled missing value at index 2401 with last valid value for Customer_ID CUS_0x3ce3.
# Filled missing value at index 2403 with last valid value for Customer_ID CUS_0x3ce3.
# Filled missing value at index 2405 with last valid value for Customer_ID CUS_0x3ce3.
# Filled missing value at index 2409 with last valid value for Customer_ID CUS_0xa706.
# Filled missing value at index 2421 with last valid value for Customer_ID CUS_0x9983.
# Filled missing value at index 2436 with last valid value for Customer_ID CUS_0x1df1.
# Filled missing value at index 2458 with last valid value for Customer_ID CUS_0x86b.
# Filled missing value at index 2468 with last valid value for Customer_ID CUS_0x98f9.
# Filled missing value at index 2493 with last valid value for Customer_ID CUS_0x481f.
# Filled missing value at index 2508 with last valid value for Customer_ID CUS_0xbf19.
# Filled missing value at index 2511 with last valid value for Customer_ID CUS_0xbf19.
# Filled missing value at index 2512 with value from index 2513.
# Filled missing value at index 2515 with last valid value for Customer_ID CUS_0xa501.
# Filled missing value at index 2525 with last valid value for Customer_ID CUS_0x2602.
# Filled missing value at index 2534 with last valid value for Customer_ID CUS_0x96e.
# Filled missing value at index 2561 with last valid value for Customer_ID CUS_0x3b3f.
# Filled missing value at index 2566 with last valid value for Customer_ID CUS_0x3b3f.
# Filled missing value at index 2572 with last valid value for Customer_ID CUS_0x9bc4.
# Filled missing value at index 2573 with last valid value for Customer_ID CUS_0x9bc4.
# Filled missing value at index 2580 with last valid value for Customer_ID CUS_0x62a4.
# Filled missing value at index 2593 with last valid value for Customer_ID CUS_0x62f0.
# Filled missing value at index 2597 with last valid value for Customer_ID CUS_0x62f0.
# Filled missing value at index 2604 with last valid value for Customer_ID CUS_0x342a.
# Filled missing value at index 2605 with last valid value for Customer_ID CUS_0x342a.
# Filled missing value at index 2626 with last valid value for Customer_ID CUS_0x7c55.
# Filled missing value at index 2634 with last valid value for Customer_ID CUS_0xa835.
# Filled missing value at index 2636 with last valid value for Customer_ID CUS_0xa835.
# Filled missing value at index 2643 with last valid value for Customer_ID CUS_0x467f.
# Filled missing value at index 2650 with last valid value for Customer_ID CUS_0x7590.
# Filled missing value at index 2663 with last valid value for Customer_ID CUS_0x515a.
# Filled missing value at index 2672 with value from index 2673.
# Filled missing value at index 2681 with last valid value for Customer_ID CUS_0x6346.
# Filled missing value at index 2683 with last valid value for Customer_ID CUS_0x6346.
# Filled missing value at index 2688 with value from index 2690.
# Filled missing value at index 2689 with value from index 2690.
# Filled missing value at index 2692 with last valid value for Customer_ID CUS_0x481c.
# Filled missing value at index 2697 with last valid value for Customer_ID CUS_0xa1ea.
# Filled missing value at index 2702 with last valid value for Customer_ID CUS_0xa1ea.
# Filled missing value at index 2705 with last valid value for Customer_ID CUS_0x70b2.
# Filled missing value at index 2714 with last valid value for Customer_ID CUS_0xc365.
# Filled missing value at index 2725 with last valid value for Customer_ID CUS_0x8efa.
# Filled missing value at index 2735 with last valid value for Customer_ID CUS_0x9783.
# Filled missing value at index 2742 with last valid value for Customer_ID CUS_0x6a17.
# Filled missing value at index 2749 with last valid value for Customer_ID CUS_0x8c03.
# Filled missing value at index 2751 with last valid value for Customer_ID CUS_0x8c03.
# Filled missing value at index 2754 with last valid value for Customer_ID CUS_0xadf6.
# Filled missing value at index 2755 with last valid value for Customer_ID CUS_0xadf6.
# Filled missing value at index 2760 with value from index 2761.
# Filled missing value at index 2763 with last valid value for Customer_ID CUS_0xa166.
# Filled missing value at index 2767 with last valid value for Customer_ID CUS_0xa166.
# Filled missing value at index 2770 with last valid value for Customer_ID CUS_0x7d27.
# Filled missing value at index 2774 with last valid value for Customer_ID CUS_0x7d27.
# Filled missing value at index 2796 with last valid value for Customer_ID CUS_0xab3b.
# Filled missing value at index 2806 with last valid value for Customer_ID CUS_0xf43.
# Filled missing value at index 2808 with value from index 2809.
# Filled missing value at index 2810 with last valid value for Customer_ID CUS_0x345b.
# Filled missing value at index 2825 with last valid value for Customer_ID CUS_0x3d51.
# Filled missing value at index 2826 with last valid value for Customer_ID CUS_0x3d51.
# Filled missing value at index 2829 with last valid value for Customer_ID CUS_0x3d51.
# Filled missing value at index 2848 with value from index 2849.
# Filled missing value at index 2859 with last valid value for Customer_ID CUS_0x9c4.
# Filled missing value at index 2863 with last valid value for Customer_ID CUS_0x9c4.
# Filled missing value at index 2872 with value from index 2874.
# Filled missing value at index 2873 with value from index 2874.
# Filled missing value at index 2877 with last valid value for Customer_ID CUS_0x602d.
# Filled missing value at index 2883 with last valid value for Customer_ID CUS_0x63dd.
# Filled missing value at index 2885 with last valid value for Customer_ID CUS_0x63dd.
# Filled missing value at index 2892 with last valid value for Customer_ID CUS_0x3f27.
# Filled missing value at index 2905 with last valid value for Customer_ID CUS_0xc247.
# Filled missing value at index 2908 with last valid value for Customer_ID CUS_0xc247.
# Filled missing value at index 2910 with last valid value for Customer_ID CUS_0xc247.
# Filled missing value at index 2911 with last valid value for Customer_ID CUS_0xc247.
# Filled missing value at index 2917 with last valid value for Customer_ID CUS_0xc723.
# Filled missing value at index 2919 with last valid value for Customer_ID CUS_0xc723.
# Filled missing value at index 2922 with last valid value for Customer_ID CUS_0xa213.
# Filled missing value at index 2923 with last valid value for Customer_ID CUS_0xa213.
# Filled missing value at index 2925 with last valid value for Customer_ID CUS_0xa213.
# Filled missing value at index 2939 with last valid value for Customer_ID CUS_0x7f61.
# Filled missing value at index 2955 with last valid value for Customer_ID CUS_0x47b2.
# Filled missing value at index 2963 with last valid value for Customer_ID CUS_0x9338.
# Filled missing value at index 2971 with last valid value for Customer_ID CUS_0x6102.
# Filled missing value at index 2989 with last valid value for Customer_ID CUS_0xa560.
# Filled missing value at index 2995 with last valid value for Customer_ID CUS_0x7fe3.
# Filled missing value at index 3004 with last valid value for Customer_ID CUS_0x4c3e.
# Filled missing value at index 3012 with last valid value for Customer_ID CUS_0x41e4.
# Filled missing value at index 3018 with last valid value for Customer_ID CUS_0x2484.
# Filled missing value at index 3047 with last valid value for Customer_ID CUS_0x8b96.
# Filled missing value at index 3067 with last valid value for Customer_ID CUS_0xbda2.
# Filled missing value at index 3086 with last valid value for Customer_ID CUS_0x7812.
# Filled missing value at index 3088 with value from index 3089.
# Filled missing value at index 3094 with last valid value for Customer_ID CUS_0xc23d.
# Filled missing value at index 3097 with last valid value for Customer_ID CUS_0x93bb.
# Filled missing value at index 3120 with value from index 3121.
# Filled missing value at index 3130 with last valid value for Customer_ID CUS_0xc081.
# Filled missing value at index 3133 with last valid value for Customer_ID CUS_0xc081.
# Filled missing value at index 3139 with last valid value for Customer_ID CUS_0x6345.
# Filled missing value at index 3148 with last valid value for Customer_ID CUS_0xc6bb.
# Filled missing value at index 3150 with last valid value for Customer_ID CUS_0xc6bb.
# Filled missing value at index 3165 with last valid value for Customer_ID CUS_0x20e0.
# Filled missing value at index 3169 with last valid value for Customer_ID CUS_0x3af5.
# Filled missing value at index 3170 with last valid value for Customer_ID CUS_0x3af5.
# Filled missing value at index 3178 with last valid value for Customer_ID CUS_0xa9e3.
# Filled missing value at index 3179 with last valid value for Customer_ID CUS_0xa9e3.
# Filled missing value at index 3183 with last valid value for Customer_ID CUS_0xa9e3.
# Filled missing value at index 3191 with last valid value for Customer_ID CUS_0x3fa8.
# Filled missing value at index 3197 with last valid value for Customer_ID CUS_0x791e.
# Filled missing value at index 3201 with last valid value for Customer_ID CUS_0x9953.
# Filled missing value at index 3207 with last valid value for Customer_ID CUS_0x9953.
# Filled missing value at index 3208 with value from index 3209.
# Filled missing value at index 3213 with last valid value for Customer_ID CUS_0xaf1b.
# Filled missing value at index 3215 with last valid value for Customer_ID CUS_0xaf1b.
# Filled missing value at index 3232 with value from index 3233.
# Filled missing value at index 3235 with last valid value for Customer_ID CUS_0x2b8e.
# Filled missing value at index 3236 with last valid value for Customer_ID CUS_0x2b8e.
# Filled missing value at index 3240 with value from index 3241.
# Filled missing value at index 3251 with last valid value for Customer_ID CUS_0x2e31.
# Filled missing value at index 3263 with last valid value for Customer_ID CUS_0x4f13.
# Filled missing value at index 3266 with last valid value for Customer_ID CUS_0x9eec.
# Filled missing value at index 3270 with last valid value for Customer_ID CUS_0x9eec.
# Filled missing value at index 3276 with last valid value for Customer_ID CUS_0x5fbf.
# Filled missing value at index 3283 with last valid value for Customer_ID CUS_0x4c1e.
# Filled missing value at index 3289 with last valid value for Customer_ID CUS_0xaac3.
# Filled missing value at index 3292 with last valid value for Customer_ID CUS_0xaac3.
# Filled missing value at index 3302 with last valid value for Customer_ID CUS_0x2041.
# Filled missing value at index 3316 with last valid value for Customer_ID CUS_0x7b15.
# Filled missing value at index 3326 with last valid value for Customer_ID CUS_0x80b1.
# Filled missing value at index 3342 with last valid value for Customer_ID CUS_0x942a.
# Filled missing value at index 3348 with last valid value for Customer_ID CUS_0xe94.
# Filled missing value at index 3351 with last valid value for Customer_ID CUS_0xe94.
# Filled missing value at index 3353 with last valid value for Customer_ID CUS_0x5d7e.
# Filled missing value at index 3358 with last valid value for Customer_ID CUS_0x5d7e.
# Filled missing value at index 3365 with last valid value for Customer_ID CUS_0x3474.
# Filled missing value at index 3366 with last valid value for Customer_ID CUS_0x3474.
# Filled missing value at index 3381 with last valid value for Customer_ID CUS_0x9776.
# Filled missing value at index 3385 with last valid value for Customer_ID CUS_0x6632.
# Filled missing value at index 3388 with last valid value for Customer_ID CUS_0x6632.
# Filled missing value at index 3408 with value from index 3409.
# Filled missing value at index 3411 with last valid value for Customer_ID CUS_0x4bdf.
# Filled missing value at index 3416 with value from index 3417.
# Filled missing value at index 3445 with last valid value for Customer_ID CUS_0x3d41.
# Filled missing value at index 3447 with last valid value for Customer_ID CUS_0x3d41.
# Filled missing value at index 3464 with value from index 3465.
# Filled missing value at index 3472 with value from index 3473.
# Filled missing value at index 3477 with last valid value for Customer_ID CUS_0x7799.
# Filled missing value at index 3484 with last valid value for Customer_ID CUS_0x7888.
# Filled missing value at index 3488 with value from index 3489.
# Filled missing value at index 3494 with last valid value for Customer_ID CUS_0x1d3e.
# Filled missing value at index 3502 with last valid value for Customer_ID CUS_0xa83a.
# Filled missing value at index 3507 with last valid value for Customer_ID CUS_0x43c6.
# Filled missing value at index 3510 with last valid value for Customer_ID CUS_0x43c6.
# Filled missing value at index 3523 with last valid value for Customer_ID CUS_0x8d4f.
# Filled missing value at index 3527 with last valid value for Customer_ID CUS_0x8d4f.
# Filled missing value at index 3531 with last valid value for Customer_ID CUS_0xa45d.
# Filled missing value at index 3533 with last valid value for Customer_ID CUS_0xa45d.
# Filled missing value at index 3536 with value from index 3537.
# Filled missing value at index 3541 with last valid value for Customer_ID CUS_0x7f32.
# Filled missing value at index 3548 with last valid value for Customer_ID CUS_0x303a.
# Filled missing value at index 3549 with last valid value for Customer_ID CUS_0x303a.
# Filled missing value at index 3550 with last valid value for Customer_ID CUS_0x303a.
# Filled missing value at index 3561 with last valid value for Customer_ID CUS_0x36d5.
# Filled missing value at index 3570 with last valid value for Customer_ID CUS_0x5155.
# Filled missing value at index 3582 with last valid value for Customer_ID CUS_0x1e6b.
# Filled missing value at index 3584 with value from index 3585.
# Filled missing value at index 3590 with last valid value for Customer_ID CUS_0x6514.
# Filled missing value at index 3600 with value from index 3601.
# Filled missing value at index 3610 with last valid value for Customer_ID CUS_0x33f0.
# Filled missing value at index 3611 with last valid value for Customer_ID CUS_0x33f0.
# Filled missing value at index 3614 with last valid value for Customer_ID CUS_0x33f0.
# Filled missing value at index 3615 with last valid value for Customer_ID CUS_0x33f0.
# Filled missing value at index 3626 with last valid value for Customer_ID CUS_0xa8e7.
# Filled missing value at index 3638 with last valid value for Customer_ID CUS_0x90d6.
# Filled missing value at index 3639 with last valid value for Customer_ID CUS_0x90d6.
# Filled missing value at index 3644 with last valid value for Customer_ID CUS_0x65f6.
# Filled missing value at index 3652 with last valid value for Customer_ID CUS_0xbbff.
# Filled missing value at index 3653 with last valid value for Customer_ID CUS_0xbbff.
# Filled missing value at index 3674 with last valid value for Customer_ID CUS_0xa6d9.
# Filled missing value at index 3677 with last valid value for Customer_ID CUS_0xa6d9.
# Filled missing value at index 3682 with last valid value for Customer_ID CUS_0x3f5f.
# Filled missing value at index 3685 with last valid value for Customer_ID CUS_0x3f5f.
# Filled missing value at index 3708 with last valid value for Customer_ID CUS_0x768c.
# Filled missing value at index 3710 with last valid value for Customer_ID CUS_0x768c.
# Filled missing value at index 3713 with last valid value for Customer_ID CUS_0x32b1.
# Filled missing value at index 3716 with last valid value for Customer_ID CUS_0x32b1.
# Filled missing value at index 3728 with value from index 3729.
# Filled missing value at index 3753 with last valid value for Customer_ID CUS_0x58f.
# Filled missing value at index 3765 with last valid value for Customer_ID CUS_0x437c.
# Filled missing value at index 3769 with last valid value for Customer_ID CUS_0x28df.
# Filled missing value at index 3789 with last valid value for Customer_ID CUS_0x2e15.
# Filled missing value at index 3797 with last valid value for Customer_ID CUS_0x52e7.
# Filled missing value at index 3809 with last valid value for Customer_ID CUS_0xac39.
# Filled missing value at index 3818 with last valid value for Customer_ID CUS_0x448c.
# Filled missing value at index 3819 with last valid value for Customer_ID CUS_0x448c.
# Filled missing value at index 3821 with last valid value for Customer_ID CUS_0x448c.
# Filled missing value at index 3839 with last valid value for Customer_ID CUS_0x76d4.
# Filled missing value at index 3849 with last valid value for Customer_ID CUS_0x695e.
# ...
# Filled missing value at index 98733 with last valid value for Customer_ID CUS_0xdcc.
# Filled missing value at index 98743 with last valid value for Customer_ID CUS_0x3278.
# Filled missing value at index 98748 with last valid value for Customer_ID CUS_0x50c4.
# Filled missing value at index 98751 with last valid value for Customer_ID CUS_0x50c4.
# Filled missing value at index 98758 with last valid value for Customer_ID CUS_0xbf23.
# Filled missing value at index 98764 with last valid value for Customer_ID CUS_0x38c2.
# Filled missing value at index 98778 with last valid value for Customer_ID CUS_0xab5f.
# Filled missing value at index 98779 with last valid value for Customer_ID CUS_0xab5f.
# Filled missing value at index 98782 with last valid value for Customer_ID CUS_0xab5f.
# Filled missing value at index 98786 with last valid value for Customer_ID CUS_0xa42f.
# Filled missing value at index 98800 with value from index 98801.
# Filled missing value at index 98805 with last valid value for Customer_ID CUS_0x7d4d.
# Filled missing value at index 98814 with last valid value for Customer_ID CUS_0x828b.
# Filled missing value at index 98819 with last valid value for Customer_ID CUS_0x231f.
# Filled missing value at index 98823 with last valid value for Customer_ID CUS_0x231f.
# Filled missing value at index 98831 with last valid value for Customer_ID CUS_0x5cc4.
# Filled missing value at index 98837 with last valid value for Customer_ID CUS_0x5fbb.
# Filled missing value at index 98846 with last valid value for Customer_ID CUS_0x7bec.
# Filled missing value at index 98847 with last valid value for Customer_ID CUS_0x7bec.
# Filled missing value at index 98852 with last valid value for Customer_ID CUS_0x1e84.
# Filled missing value at index 98857 with last valid value for Customer_ID CUS_0x5606.
# Filled missing value at index 98865 with last valid value for Customer_ID CUS_0x5fcb.
# Filled missing value at index 98870 with last valid value for Customer_ID CUS_0x5fcb.
# Filled missing value at index 98871 with last valid value for Customer_ID CUS_0x5fcb.
# Filled missing value at index 98873 with last valid value for Customer_ID CUS_0x3e03.
# Filled missing value at index 98877 with last valid value for Customer_ID CUS_0x3e03.
# Filled missing value at index 98879 with last valid value for Customer_ID CUS_0x3e03.
# Filled missing value at index 98899 with last valid value for Customer_ID CUS_0x5054.
# Filled missing value at index 98906 with last valid value for Customer_ID CUS_0x27e5.
# Filled missing value at index 98912 with value from index 98913.
# Filled missing value at index 98917 with last valid value for Customer_ID CUS_0x2002.
# Filled missing value at index 98923 with last valid value for Customer_ID CUS_0x6f95.
# Filled missing value at index 98926 with last valid value for Customer_ID CUS_0x6f95.
# Filled missing value at index 98944 with value from index 98945.
# Filled missing value at index 98951 with last valid value for Customer_ID CUS_0x9efc.
# Filled missing value at index 98952 with value from index 98953.
# Filled missing value at index 98963 with last valid value for Customer_ID CUS_0x85a2.
# Filled missing value at index 98973 with last valid value for Customer_ID CUS_0x8c51.
# Filled missing value at index 98987 with last valid value for Customer_ID CUS_0x16b6.
# Filled missing value at index 98990 with last valid value for Customer_ID CUS_0x16b6.
# Filled missing value at index 98991 with last valid value for Customer_ID CUS_0x16b6.
# Filled missing value at index 98998 with last valid value for Customer_ID CUS_0x531a.
# Filled missing value at index 98999 with last valid value for Customer_ID CUS_0x531a.
# Filled missing value at index 99005 with last valid value for Customer_ID CUS_0x50e9.
# Filled missing value at index 99007 with last valid value for Customer_ID CUS_0x50e9.
# Filled missing value at index 99012 with last valid value for Customer_ID CUS_0xb57.
# Filled missing value at index 99019 with last valid value for Customer_ID CUS_0x523e.
# Filled missing value at index 99024 with value from index 99025.
# Filled missing value at index 99028 with last valid value for Customer_ID CUS_0x9f04.
# Filled missing value at index 99029 with last valid value for Customer_ID CUS_0x9f04.
# Filled missing value at index 99036 with last valid value for Customer_ID CUS_0x21d8.
# Filled missing value at index 99039 with last valid value for Customer_ID CUS_0x21d8.
# Filled missing value at index 99041 with last valid value for Customer_ID CUS_0x2274.
# Filled missing value at index 99044 with last valid value for Customer_ID CUS_0x2274.
# Filled missing value at index 99061 with last valid value for Customer_ID CUS_0xb5e4.
# Filled missing value at index 99069 with last valid value for Customer_ID CUS_0xc429.
# Filled missing value at index 99075 with last valid value for Customer_ID CUS_0x4e14.
# Filled missing value at index 99097 with last valid value for Customer_ID CUS_0x55f0.
# Filled missing value at index 99098 with last valid value for Customer_ID CUS_0x55f0.
# Filled missing value at index 99127 with last valid value for Customer_ID CUS_0x4dc9.
# Filled missing value at index 99130 with last valid value for Customer_ID CUS_0xbb53.
# Filled missing value at index 99136 with value from index 99137.
# Filled missing value at index 99146 with last valid value for Customer_ID CUS_0x50d4.
# Filled missing value at index 99157 with last valid value for Customer_ID CUS_0xffd.
# Filled missing value at index 99168 with value from index 99170.
# Filled missing value at index 99169 with value from index 99170.
# Filled missing value at index 99171 with last valid value for Customer_ID CUS_0xa93b.
# Filled missing value at index 99174 with last valid value for Customer_ID CUS_0xa93b.
# Filled missing value at index 99188 with last valid value for Customer_ID CUS_0x6334.
# Filled missing value at index 99190 with last valid value for Customer_ID CUS_0x6334.
# Filled missing value at index 99192 with value from index 99193.
# Filled missing value at index 99194 with last valid value for Customer_ID CUS_0xb59b.
# Filled missing value at index 99197 with last valid value for Customer_ID CUS_0xb59b.
# Filled missing value at index 99212 with last valid value for Customer_ID CUS_0x2954.
# Filled missing value at index 99235 with last valid value for Customer_ID CUS_0x56e5.
# Filled missing value at index 99262 with last valid value for Customer_ID CUS_0x509d.
# Filled missing value at index 99266 with last valid value for Customer_ID CUS_0xa66c.
# Filled missing value at index 99272 with value from index 99273.
# Filled missing value at index 99280 with value from index 99283.
# Filled missing value at index 99281 with value from index 99283.
# Filled missing value at index 99282 with value from index 99283.
# Filled missing value at index 99291 with last valid value for Customer_ID CUS_0x48a.
# Filled missing value at index 99304 with value from index 99305.
# Filled missing value at index 99324 with last valid value for Customer_ID CUS_0x4af4.
# Filled missing value at index 99328 with value from index 99329.
# Filled missing value at index 99348 with last valid value for Customer_ID CUS_0x436f.
# Filled missing value at index 99356 with last valid value for Customer_ID CUS_0x870c.
# Filled missing value at index 99360 with value from index 99361.
# Filled missing value at index 99375 with last valid value for Customer_ID CUS_0x163c.
# Filled missing value at index 99383 with last valid value for Customer_ID CUS_0x7a7d.
# Filled missing value at index 99385 with last valid value for Customer_ID CUS_0x965d.
# Filled missing value at index 99386 with last valid value for Customer_ID CUS_0x965d.
# Filled missing value at index 99411 with last valid value for Customer_ID CUS_0x90a1.
# Filled missing value at index 99412 with last valid value for Customer_ID CUS_0x90a1.
# Filled missing value at index 99413 with last valid value for Customer_ID CUS_0x90a1.
# Filled missing value at index 99414 with last valid value for Customer_ID CUS_0x90a1.
# Filled missing value at index 99417 with last valid value for Customer_ID CUS_0xdfd.
# Filled missing value at index 99424 with value from index 99425.
# Filled missing value at index 99429 with last valid value for Customer_ID CUS_0x74e7.
# Filled missing value at index 99430 with last valid value for Customer_ID CUS_0x74e7.
# Filled missing value at index 99436 with last valid value for Customer_ID CUS_0x62f4.
# Filled missing value at index 99448 with value from index 99449.
# Filled missing value at index 99456 with value from index 99457.
# Filled missing value at index 99468 with last valid value for Customer_ID CUS_0x450.
# Filled missing value at index 99475 with last valid value for Customer_ID CUS_0x1956.
# Filled missing value at index 99482 with last valid value for Customer_ID CUS_0x862b.
# Filled missing value at index 99490 with last valid value for Customer_ID CUS_0x290c.
# Filled missing value at index 99491 with last valid value for Customer_ID CUS_0x290c.
# Filled missing value at index 99499 with last valid value for Customer_ID CUS_0xb5c3.
# Filled missing value at index 99510 with last valid value for Customer_ID CUS_0x504e.
# Filled missing value at index 99513 with last valid value for Customer_ID CUS_0x10f9.
# Filled missing value at index 99521 with last valid value for Customer_ID CUS_0xbbdd.
# Filled missing value at index 99523 with last valid value for Customer_ID CUS_0xbbdd.
# Filled missing value at index 99527 with last valid value for Customer_ID CUS_0xbbdd.
# Filled missing value at index 99531 with last valid value for Customer_ID CUS_0x85dd.
# Filled missing value at index 99532 with last valid value for Customer_ID CUS_0x85dd.
# Filled missing value at index 99539 with last valid value for Customer_ID CUS_0xc22f.
# Filled missing value at index 99542 with last valid value for Customer_ID CUS_0xc22f.
# Filled missing value at index 99552 with value from index 99554.
# Filled missing value at index 99553 with value from index 99554.
# Filled missing value at index 99555 with last valid value for Customer_ID CUS_0x4f88.
# Filled missing value at index 99568 with value from index 99569.
# Filled missing value at index 99572 with last valid value for Customer_ID CUS_0x1b3b.
# Filled missing value at index 99579 with last valid value for Customer_ID CUS_0x4c83.
# Filled missing value at index 99587 with last valid value for Customer_ID CUS_0x544.
# Filled missing value at index 99588 with last valid value for Customer_ID CUS_0x544.
# Filled missing value at index 99593 with last valid value for Customer_ID CUS_0x94de.
# Filled missing value at index 99601 with last valid value for Customer_ID CUS_0x5d6d.
# Filled missing value at index 99615 with last valid value for Customer_ID CUS_0x2829.
# Filled missing value at index 99629 with last valid value for Customer_ID CUS_0x738b.
# Filled missing value at index 99634 with last valid value for Customer_ID CUS_0x296f.
# Filled missing value at index 99642 with last valid value for Customer_ID CUS_0x1d9e.
# Filled missing value at index 99648 with value from index 99649.
# Filled missing value at index 99650 with last valid value for Customer_ID CUS_0x2e91.
# Filled missing value at index 99652 with last valid value for Customer_ID CUS_0x2e91.
# Filled missing value at index 99656 with value from index 99657.
# Filled missing value at index 99664 with value from index 99665.
# Filled missing value at index 99669 with last valid value for Customer_ID CUS_0xb09.
# Filled missing value at index 99676 with last valid value for Customer_ID CUS_0xbd8f.
# Filled missing value at index 99684 with last valid value for Customer_ID CUS_0x68ea.
# Filled missing value at index 99686 with last valid value for Customer_ID CUS_0x68ea.
# Filled missing value at index 99690 with last valid value for Customer_ID CUS_0x1132.
# Filled missing value at index 99703 with last valid value for Customer_ID CUS_0x1ea8.
# Filled missing value at index 99714 with last valid value for Customer_ID CUS_0xadbd.
# Filled missing value at index 99728 with value from index 99729.
# Filled missing value at index 99730 with last valid value for Customer_ID CUS_0x6294.
# Filled missing value at index 99736 with value from index 99737.
# Filled missing value at index 99745 with last valid value for Customer_ID CUS_0x9ce3.
# Filled missing value at index 99753 with last valid value for Customer_ID CUS_0x4a8f.
# Filled missing value at index 99763 with last valid value for Customer_ID CUS_0x1b07.
# Filled missing value at index 99768 with value from index 99769.
# Filled missing value at index 99784 with value from index 99785.
# Filled missing value at index 99786 with last valid value for Customer_ID CUS_0x62f5.
# Filled missing value at index 99790 with last valid value for Customer_ID CUS_0x62f5.
# Filled missing value at index 99792 with value from index 99793.
# Filled missing value at index 99794 with last valid value for Customer_ID CUS_0x334b.
# Filled missing value at index 99796 with last valid value for Customer_ID CUS_0x334b.
# Filled missing value at index 99800 with value from index 99801.
# Filled missing value at index 99809 with last valid value for Customer_ID CUS_0x64f0.
# Filled missing value at index 99815 with last valid value for Customer_ID CUS_0x64f0.
# Filled missing value at index 99816 with value from index 99818.
# Filled missing value at index 99817 with value from index 99818.
# Filled missing value at index 99821 with last valid value for Customer_ID CUS_0x40ad.
# Filled missing value at index 99839 with last valid value for Customer_ID CUS_0x8788.
# Filled missing value at index 99855 with last valid value for Customer_ID CUS_0x3048.
# Filled missing value at index 99865 with last valid value for Customer_ID CUS_0x1d18.
# Filled missing value at index 99866 with last valid value for Customer_ID CUS_0x1d18.
# Filled missing value at index 99888 with value from index 99889.
# Filled missing value at index 99892 with last valid value for Customer_ID CUS_0x89aa.
# Filled missing value at index 99906 with last valid value for Customer_ID CUS_0xa053.
# Filled missing value at index 99910 with last valid value for Customer_ID CUS_0xa053.
# Filled missing value at index 99928 with value from index 99929.
# Filled missing value at index 99943 with last valid value for Customer_ID CUS_0xad4f.
# Filled missing value at index 99944 with value from index 99945.
# Filled missing value at index 99955 with last valid value for Customer_ID CUS_0x2084.
# Filled missing value at index 99963 with last valid value for Customer_ID CUS_0x372c.
# Filled missing value at index 99975 with last valid value for Customer_ID CUS_0xf16.
# Filled missing value at index 99978 with last valid value for Customer_ID CUS_0xaf61.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 df['Monthly_Inhand_Salary'] = check_and_copy_row_data(df, 'Monthly_Inhand_Salary')
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_array(key, value)
#    3967 elif isinstance(value, DataFrame):
# -> 3968     self._set_item_frame_value(key, value)
#    3969 elif (
#    3970     is_list_like(value)
#    3971     and not self.columns.is_unique
#    3972     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3973 ):
#    3974     # Column to set is duplicated
#    3975     self._setitem_array([key], value)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4098, in DataFrame._set_item_frame_value(self, key, value)
#    4096 len_cols = 1 if is_scalar(cols) else len(cols)
#    4097 if len_cols != len(value.columns):
# -> 4098     raise ValueError("Columns must be same length as key")
#    4100 # align right-hand-side columns if self.columns
#    4101 # is multi-index and self[key] is a sub-frame
#    4102 if isinstance(self.columns, MultiIndex) and isinstance(
#    4103     loc, (slice, Series, np.ndarray, Index)
#    4104 ):
#
# ValueError: Columns must be same length as key

# %%
#Annual Income And Monthly Inhand Salary
df['Annual_Income'] = df['Annual_Income'].map(lambda x: x.rstrip('_'))
df['Annual_Income'] = df['Annual_Income'].astype('float64')

# %%
#Age
#df['Age'].unique()
df[df['Age']>'55']['Age']

# %%
df['Age'] = df['Age'].map(lambda x: x.lstrip('-').rstrip('_'))

# %%
df['Age'] = df['Age'].astype('int64')
df['Age'].dtypes

# %%
#Type of Loan
df['Type_of_Loan'] = df['Type_of_Loan'].fillna('NA')

# %%
#Delay from due date
#df['Delay_from_due_date'].unique()
df['Delay_from_due_date'] = df.apply(lambda x: (x['Delay_from_due_date']*-1) if x['Delay_from_due_date'] < 0 else x['Delay_from_due_date'], axis=1)

# %%
df['Num_of_Delayed_Payment'].unique()

# %%
df['Delay_from_due_date'] = df['Delay_from_due_date'].astype('str')

# %%
df['Num_of_Delayed_Payment'] = df['Delay_from_due_date'].map(lambda x: x.lstrip('-').rstrip('_'))
